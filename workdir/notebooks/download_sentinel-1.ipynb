# %%
import os
import sys

os.chdir('/work')
print(os.getcwd())
# Out:
# /work

# %%
from tools.download_sentinel import download_s1_slc

# %%
asf_file = "tools/asf-datapool-results-2025-05-05_06-17-37.geojson"
folder_out = "/mnt/data_storage/"
username = "gray_19"
password = "Yasu140109n!"

download_s1_slc(asf_file, folder_out, username, password)
# Out:
# >>> Warning: urs.earthdata.nasa.gov existed, nothing will be done. If you want to overwrite the existed record, set overwrite=True
# >>> Total | :   0%|          | 0/191 [00:00<?, ?files/s]
# S1A_IW_SLC__1SDV_20221229T111532_20221229T111600_046545_0593E2_85B1.zip was downloaded entirely. skiping download
# S1A_IW_SLC__1SDV_20221217T111532_20221217T111600_046370_058DF6_C733.zip was downloaded entirely. skiping download
# S1A_IW_SLC__1SDV_20221205T111533_20221205T111601_046195_0587FF_D996.zip was downloaded entirely. skiping download
# S1A_IW_SLC__1SDV_20221123T111534_20221123T111602_046020_058209_C1CC.zip was downloaded entirely. skiping download
# S1A_IW_SLC__1SDV_20221111T111534_20221111T111602_045845_057C1D_22A3.zip was downloaded entirely. skiping download
# S1A_IW_SLC__1SDV_20221030T111534_20221030T111602_045670_057638_7B33.zip was downloaded entirely. skiping download
# ...
